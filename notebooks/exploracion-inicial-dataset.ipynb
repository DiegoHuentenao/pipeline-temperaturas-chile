# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

raw_temperatura = pd.read_csv('https://datos.gob.cl/uploads/recursos/Temperatura.csv')

# %%
raw_temperatura.head()
#El primer vistazo evidencia la necesidad de reestructurar y limpiar los datos.
# Out:
#    180005;"Chacalluta  Arica Ap.";"18&deg 21' 5'' S";63;2015;1;1;"18.7";"23.4"
# 0  180005;"Chacalluta   Arica Ap.";"18&deg 21' 5'' S";63;2015;1;2;"20...
# 1  180005;"Chacalluta   Arica Ap.";"18&deg 21' 5'' S";63;2015;1;3;"20...
# 2  180005;"Chacalluta   Arica Ap.";"18&deg 21' 5'' S";63;2015;1;4;"19...
# 3  180005;"Chacalluta   Arica Ap.";"18&deg 21' 5'' S";63;2015;1;5;"19...
# 4  180005;"Chacalluta   Arica Ap.";"18&deg 21' 5'' S";63;2015;1;6;"19...

# %%
temperatura = pd.read_csv('https://datos.gob.cl/uploads/recursos/Temperatura.csv',
                             sep=';',
                             header=None,
                             #dataset no incluye header
                             )
nombre_columnas = ['id-estacion','nombre-estacion','latitud','longitud','altura','año','mes','dia','temperatura-minima','temperatura-maxima']
#nombre de columnas rescatadas de la documentación del autor del dataset.

# %%
len(temperatura[temperatura.isnull().any(axis=1)])
#85
import numpy as np

# %%
temperatura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5958 entries, 0 to 5957
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5954 non-null   float64
#  1   1       5954 non-null   object
#  2   2       5954 non-null   object
#  3   3       5954 non-null   float64
#  4   4       5954 non-null   float64
#  5   5       5954 non-null   float64
#  6   6       5954 non-null   float64
#  7   7       5934 non-null   float64
#  8   8       5893 non-null   float64
# dtypes: float64(7), object(2)
# memory usage: 419.1+ KB

# %%
temperatura.shape
# Out:
# (5958, 9)

# %%
temperatura.describe()
# Out:
#                    0            3       4            5            6  \
# count    5954.000000  5954.000000  5954.0  5954.000000  5954.000000
# mean   389139.656533   241.577259  2015.0     3.504703    15.592039
# std    136736.557232   400.905899     0.0     1.709568     8.729487
# min    180005.000000    10.000000  2015.0     1.000000     1.000000
# 25%    330019.000000    48.000000  2015.0     2.000000     8.000000
# 50%    370033.000000   113.000000  2015.0     4.000000    16.000000
# 75%    450004.000000   306.000000  2015.0     5.000000    23.000000
# max    950001.000000  2293.000000  2015.0     6.000000    31.000000
#
#                  7            8
# count  5934.000000  5893.000000
# mean      8.593714    18.993653
# std       6.228227     7.675573
# min     -17.600000   -12.000000
# 25%       4.300000    14.200000
# 50%       8.500000    19.800000
# 75%      13.100000    24.300000
# max      23.600000    36.800000
